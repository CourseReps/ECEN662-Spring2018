# %%
import pandas as pd

# %%
score = pd.read_csv('/home/amrita95/Desktop/Estimation and Detection/project/deliveries.csv')
match = pd.read_csv('/home/amrita95/Desktop/Estimation and Detection/project/matches.csv')

# %%
score.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>match_id</th>
#       <th>inning</th>
#       <th>batting_team</th>
#       <th>bowling_team</th>
#       <th>over</th>
#       <th>ball</th>
#       <th>batsman</th>
#       <th>non_striker</th>
#       <th>bowler</th>
#       <th>is_super_over</th>
#       <th>...</th>
#       <th>bye_runs</th>
#       <th>legbye_runs</th>
#       <th>noball_runs</th>
#       <th>penalty_runs</th>
#       <th>batsman_runs</th>
#       <th>extra_runs</th>
#       <th>total_runs</th>
#       <th>player_dismissed</th>
#       <th>dismissal_kind</th>
#       <th>fielder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...
